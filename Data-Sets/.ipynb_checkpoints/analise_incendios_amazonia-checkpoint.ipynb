# %%
#Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Carregando data set e separando por virgula e definindo encoding
# pode usar o comando: usecols=[3,6,6] para selecionar as colunas que devem apresentar no data set
df = pd.read_csv('C:/Users/Marcos/Documents/Repositorio_Git/Analise-Dados-Python-Pandas/Data-Sets/ds_focus_incendios_amazonia.csv',
                 sep=',',encoding='cp1252',usecols=[0,1,2,3,4])

# %%
#tamanho do data frame
df.shape
# Out:
# (6454, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of        ano         uf        mes  numero        data
# 0     1998       Acre    Janeiro     0.0  1998-01-01
# 1     1999       Acre    Janeiro     0.0  1999-01-01
# 2     2000       Acre    Janeiro     0.0  2000-01-01
# 3     2001       Acre    Janeiro     0.0  2001-01-01
# 4     2002       Acre    Janeiro     0.0  2002-01-01
# 5     2003       Acre    Janeiro    10.0  2003-01-01
# 6     2004       Acre    Janeiro     0.0  2004-01-01
# 7     2005       Acre    Janeiro    12.0  2005-01-01
# 8     2006       Acre    Janeiro     4.0  2006-01-01
# 9     2007       Acre    Janeiro     0.0  2007-01-01
# 10    2008       Acre    Janeiro     0.0  2008-01-01
# 11    2009       Acre    Janeiro     0.0  2009-01-01
# 12    2010       Acre    Janeiro     1.0  2010-01-01
# 13    2011       Acre    Janeiro     0.0  2011-01-01
# 14    2012       Acre    Janeiro     0.0  2012-01-01
# 15    2013       Acre    Janeiro     0.0  2013-01-01
# ...

# %%
#Mostra as cinco primeiras linhas do data frame
df.head(5)
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %%
#Trocando os nomes das colunas
df.columns=['ano','uf','mes','numero','data']
df.head()
# Out:
#     ano    uf      mes  numero        data
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %%
#Conta a quantidade de linhas 
df.count()
# Out:
# year      6454
# state     6454
# month     6454
# number    6454
# date      6454
# dtype: int64

# %%
#traz as ultimas linhas
df.tail()
# Out:
#        ano         uf       mes  numero        data
# 6449  2012  Tocantins  Dezembro   128.0  2012-01-01
# 6450  2013  Tocantins  Dezembro    85.0  2013-01-01
# 6451  2014  Tocantins  Dezembro   223.0  2014-01-01
# 6452  2015  Tocantins  Dezembro   373.0  2015-01-01
# 6453  2016  Tocantins  Dezembro   119.0  2016-01-01

# %%
#traz valores numericos do data frame
df.describe()
# Out:
#                ano       numero
# count  6454.000000  6454.000000
# mean   2007.461729   108.293163
# std       5.746654   190.812242
# min    1998.000000     0.000000
# 25%    2002.000000     3.000000
# 50%    2007.000000    24.000000
# 75%    2012.000000   113.000000
# max    2017.000000   998.000000

# %%
#mostra o que cada coluna é 
df.dtypes
# Out:
# year        int64
# state      object
# month      object
# number    float64
# date       object
# dtype: object

# %%
#quantos registro tem por ano
df['uf'].value_counts()
# Out:
# Rio                 717
# Paraiba             478
# Mato Grosso         478
# Alagoas             240
# Amazonas            239
# Espirito Santo      239
# Sergipe             239
# Distrito Federal    239
# Amapa               239
# Sao Paulo           239
# Acre                239
# Roraima             239
# Maranhao            239
# Goias               239
# Pernambuco          239
# Rondonia            239
# Pará                239
# Santa Catarina      239
# Piau                239
# Tocantins           239
# Bahia               239
# Ceara               239
# Minas Gerais        239
# Name: uf, dtype: int64

# %%
# %matplotlib inline
plt.xlabel('Estado')
plt.ylabel('Quantidade')
plt.title('Quantitativo')
df['uf'].value_counts().plot.bar()

# %%
#trazendo valores unicos no data frame
df['uf'].unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Minas Gerais', 'Pará', 'Paraiba', 'Pernambuco',
#        'Piau', 'Rio', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins'], dtype=object)

# %%
#Criando um novo data frame pra analisar somente os dados do rio de janeiro que tem maior foco de incendio
df_rio = df[df['uf']== 'Rio']
df_rio.head(5)
# Out:
#        ano   uf      mes  numero        data
# 4303  1998  Rio  Janeiro     0.0  1998-01-01
# 4304  1999  Rio  Janeiro     0.0  1999-01-01
# 4305  2000  Rio  Janeiro     0.0  2000-01-01
# 4306  2001  Rio  Janeiro     0.0  2001-01-01
# 4307  2002  Rio  Janeiro     0.0  2002-01-01

# %%
#trazendo focos somente do mes de maio
df_rio[df_rio['mes'].str.contains('Maio')]
# Out:
#        ano   uf   mes  numero        data
# 4383  1998  Rio  Maio     0.0  1998-01-01
# 4384  1999  Rio  Maio     7.0  1999-01-01
# 4385  2000  Rio  Maio     5.0  2000-01-01
# 4386  2001  Rio  Maio     4.0  2001-01-01
# 4387  2002  Rio  Maio     4.0  2002-01-01
# 4388  2003  Rio  Maio     1.0  2003-01-01
# 4389  2004  Rio  Maio     0.0  2004-01-01
# 4390  2005  Rio  Maio    11.0  2005-01-01
# 4391  2006  Rio  Maio     4.0  2006-01-01
# 4392  2007  Rio  Maio     2.0  2007-01-01
# 4393  2008  Rio  Maio     0.0  2008-01-01
# 4394  2009  Rio  Maio    37.0  2009-01-01
# 4395  2010  Rio  Maio     6.0  2010-01-01
# 4396  2011  Rio  Maio    17.0  2011-01-01
# 4397  2012  Rio  Maio    18.0  2012-01-01
# 4398  2013  Rio  Maio    16.0  2013-01-01
# 4399  2014  Rio  Maio    20.0  2014-01-01
# 4400  2015  Rio  Maio    21.0  2015-01-01
# 4401  2016  Rio  Maio    30.0  2016-01-01
# 4402  2017  Rio  Maio    15.0  2017-01-01
# 4622  1998  Rio  Maio     0.0  1998-01-01
# ...

# %%
#Contando a quantidade de registros no caso 60
df_rio[df_rio['mes'].str.contains('Maio')].count()
# Out:
# ano       60
# uf        60
# mes       60
# numero    60
# data      60
# dtype: int64

# %%
df_rio['mes'].value_counts().plot.barh()
